# %% [markdown]
# <a href="https://colab.research.google.com/github/TonoNP/CLASE-1/blob/main/CLASE_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title("Primera gráfica: onda seno")
plt.show()

# %%
A = np.array([[3,-5,6],[1,-1,-1],[8,9,15]])
A_inv = np.linalg.inv(A)
print(A_inv)
# Out:
# [[-0.03015075  0.64824121  0.05527638]
#  [-0.11557789 -0.01507538  0.04522613]
#  [ 0.08542714 -0.33668342  0.01005025]]

# %%
import numpy as np

# Definir la matriz original
A = np.array([[3, -5, 6],
              [1, -1, -1],
              [8,  9, 15]])

# Calcular la inversa
A_inv = np.linalg.inv(A)

# Multiplicación A * A_inv
resultado = np.dot(A, A_inv)

print("Matriz original A:")
print(A)

print("\nInversa de A:")
print(A_inv)

print("\nComprobación A * A_inv:")
print(resultado)

# Opcional: comparar con la identidad
print("\nMatriz identidad esperada:")
print(np.eye(3))
# Out:
# Matriz original A:
# [[ 3 -5  6]
#  [ 1 -1 -1]
#  [ 8  9 15]]
#
# Inversa de A:
# [[-0.03015075  0.64824121  0.05527638]
#  [-0.11557789 -0.01507538  0.04522613]
#  [ 0.08542714 -0.33668342  0.01005025]]
#
# Comprobación A * A_inv:
# [[ 1.00000000e+00  0.00000000e+00  4.16333634e-17]
#  [-2.77555756e-17  1.00000000e+00  1.73472348e-17]
#  [ 2.77555756e-17 -2.22044605e-16  1.00000000e+00]]
#
# Matriz identidad esperada:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
x = np.linspace(0, 1*np.pi, 10000)
y1 = np.sin(x)
y2 = np.sin(6*x)
y_total = y1 + y2

plt.plot(x, y1, label="Onda 1 (k)")
plt.plot(x, y2, label="Onda 2 (2k)")
plt.plot(x, y_total, label="Superposición", linewidth=2)
plt.legend()
plt.title("Superposición de ondas")
plt.show()

# %%
X, Y = np.meshgrid(np.linspace(0, 5, 50), np.linspace(0, 5, 50))
Z = np.sin(2*np.pi*X) * 5*np.sin(np.pi*Y)

plt.imshow(Z, extent=(0,5,0,5), origin="lower", cmap="viridis")
plt.colorbar(label="Amplitud")
plt.title("Onda estacionaria en 2D")
plt.show()

# %%
# @title Texto de título predeterminado
import numpy as np

# Definir la matriz original
A = np.array([[3, -5, 6],
              [1, -1, -1],
              [8,  9, 15]])

# Calcular la inversa
A_inv = np.linalg.inv(A)

# Multiplicación A * A_inv
resultado = np.dot(A, A_inv)

print("Matriz original A:")
print(A)

print("\nInversa de A:")
print(A_inv)

# Redondear el resultado a 3 decimales
resultado_redondeado = np.round(resultado, decimals=3)

print("Matriz A * A_inv redondeada:")
print(resultado_redondeado)

# Opcional: comparar con la identidad
print("\nMatriz identidad esperada:")
print(np.eye(3))
# Out:
# Matriz original A:
# [[ 3 -5  6]
#  [ 1 -1 -1]
#  [ 8  9 15]]
#
# Inversa de A:
# [[-0.03015075  0.64824121  0.05527638]
#  [-0.11557789 -0.01507538  0.04522613]
#  [ 0.08542714 -0.33668342  0.01005025]]
# Matriz A * A_inv redondeada:
# [[ 1.  0.  0.]
#  [-0.  1.  0.]
#  [ 0. -0.  1.]]
#
# Matriz identidad esperada:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
